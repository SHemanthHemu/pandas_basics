# %%
import pandas as pd

# %%
# reading the data 
employees_df = pd.read_csv(filepath_or_buffer=r"C:\Users\heman\Desktop\chat gpt\data\input\realistic_employee_data.csv")
employees_df
# Out:
#      EmployeeID             Name   Department  Location JoiningDate    Salary  \
# 0          1001   William Chaney    Marketing    Boston  2024-08-23  160169.0
# 1          1002    Andre Stewart        Sales   Seattle  2016-07-27   58125.0
# 2          1003  Nicole Sandoval      Finance    Austin  2022-10-10   86059.0
# 3          1004      Billy Lopez        Sales  New York  2017-02-01  153409.0
# 4          1005    Charles Wyatt        Sales    Austin  2016-05-10  198159.0
# ..          ...              ...          ...       ...         ...       ...
# 995        1996  Margaret Duncan           IT   Seattle  2018-06-01  136120.0
# 996        1997    Corey Johnson        Sales  New York  2024-04-13  164889.0
# 997        1998     Samuel White  Engineering  New York  2020-10-01  191130.0
# 998        1999     Andrew Clark  Engineering    Austin  2024-05-19  124637.0
# 999        2000     John Salazar        Sales    Boston  2019-06-22       NaN
#
# ...

# %%
# getting the over view of the data 
employees_df.head() # first 5 records 
employees_df.head(10) # first 10 records
# Out:
#    EmployeeID             Name Department  Location JoiningDate    Salary  \
# 0        1001   William Chaney  Marketing    Boston  2024-08-23  160169.0
# 1        1002    Andre Stewart      Sales   Seattle  2016-07-27   58125.0
# 2        1003  Nicole Sandoval    Finance    Austin  2022-10-10   86059.0
# 3        1004      Billy Lopez      Sales  New York  2017-02-01  153409.0
# 4        1005    Charles Wyatt      Sales    Austin  2016-05-10  198159.0
#
#    PerformanceScore  BonusEligible Gender  Age  WorkFromHome  ProjectsHandled  \
# 0              4.65          False  Other   55         False               18
# 1              3.45          False  Other   46          True               10
# 2              4.49          False  Other   37         False                7
# 3              3.90          False  Other   55         False                9
# 4              1.48          False  Other   50          True                1
#
#   Certifications
# 0            AWS
# ...

# %%
employees_df.tail() # last 5 records
employees_df.tail(10) # last 10 records
# Out:
#      EmployeeID             Name   Department  Location JoiningDate    Salary  \
# 995        1996  Margaret Duncan           IT   Seattle  2018-06-01  136120.0
# 996        1997    Corey Johnson        Sales  New York  2024-04-13  164889.0
# 997        1998     Samuel White  Engineering  New York  2020-10-01  191130.0
# 998        1999     Andrew Clark  Engineering    Austin  2024-05-19  124637.0
# 999        2000     John Salazar        Sales    Boston  2019-06-22       NaN
#
#      PerformanceScore  BonusEligible  Gender  Age  WorkFromHome  \
# 995              2.08          False  Female   33         False
# 996              1.81           True    Male   25          True
# 997              2.26           True    Male   45         False
# 998              1.97          False    Male   50          True
# 999              1.86          False    Male   30         False
#
#      ProjectsHandled Certifications
# 995                3          Azure
# 996               10            PMP
# ...

# %%
# getting the over view of the data frame 
employees_df.index
employees_df.columns
print(list[employees_df.columns])
# Out:
# list[Index(['EmployeeID', 'Name', 'Department', 'Location', 'JoiningDate', 'Salary',
#        'PerformanceScore', 'BonusEligible', 'Gender', 'Age', 'WorkFromHome',
#        'ProjectsHandled', 'Certifications'],
#       dtype='object')]

# %%
employees_df.shape # getting the shape of the df
# Out:
# (1000, 13)

# %%
employees_df.dtypes # getting the data types of the column
# Out:
# EmployeeID            int64
# Name                 object
# Department           object
# Location             object
# JoiningDate          object
# Salary              float64
# PerformanceScore    float64
# BonusEligible          bool
# Gender               object
# Age                   int64
# WorkFromHome           bool
# ProjectsHandled       int64
# Certifications       object
# dtype: object

# %%
employees_df.info() # more details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        1000 non-null   int64
#  1   Name              1000 non-null   object
#  2   Department        980 non-null    object
#  3   Location          1000 non-null   object
#  4   JoiningDate       1000 non-null   object
#  5   Salary            951 non-null    float64
#  6   PerformanceScore  971 non-null    float64
#  7   BonusEligible     1000 non-null   bool
#  8   Gender            1000 non-null   object
#  9   Age               1000 non-null   int64
#  10  WorkFromHome      1000 non-null   bool
#  11  ProjectsHandled   1000 non-null   int64
#  12  Certifications    802 non-null    object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 88.0+ KB

# %%
employees_df.memory_usage()  # to know about the memory usage
# Out:
# Index                132
# EmployeeID          8000
# Name                8000
# Department          8000
# Location            8000
# JoiningDate         8000
# Salary              8000
# PerformanceScore    8000
# BonusEligible       1000
# Gender              8000
# Age                 8000
# WorkFromHome        1000
# ProjectsHandled     8000
# Certifications      8000
# dtype: int64

# %%
# Descriptive Statistics for Numerical Data

# %%
employees_df.describe(include=['object'])
# Out:
#                  Name   Department Location JoiningDate Gender Certifications
# count            1000          980     1000        1000   1000            802
# unique            992            6        5         871      3              5
# top     Brian Sanchez  Engineering   Boston  2019-06-30  Other            AWS
# freq                2          175      203           3    358            172

# %%
# Exploring Categorical Data

# %%
employees_df['Department'].unique() # to find the unique records in a specific column
# Out:
# array(['Marketing', 'Sales', 'Finance', 'HR', 'IT', 'Engineering', nan],
#       dtype=object)

# %%
employees_df['Department'].value_counts() # to know the number of occurences of the unique recoreds
# Out:
# Department
# Engineering    175
# Marketing      172
# Sales          170
# HR             159
# Finance        153
# IT             151
# Name: count, dtype: int64

# %%
employees_df['Department'].value_counts(dropna=False) # to know the number of occurences of the unique recoreds including nan
# Out:
# Department
# Engineering    175
# Marketing      172
# Sales          170
# HR             159
# Finance        153
# IT             151
# NaN             20
# Name: count, dtype: int64

# %%
employees_df['Department'].mode() # getting the mode of the column
# Out:
# 0    Engineering
# Name: Department, dtype: object

# %%
employees_df['Department'].value_counts().idxmax() # most repeating vlaue in the column
# Out:
# 'Engineering'

# %%
# Handling Missing Data

# %%
employees_df.isnull() # will convert the data set in to boolen values
# Out:
#      EmployeeID   Name  Department  Location  JoiningDate  Salary  \
# 0         False  False       False     False        False   False
# 1         False  False       False     False        False   False
# 2         False  False       False     False        False   False
# 3         False  False       False     False        False   False
# 4         False  False       False     False        False   False
# ..          ...    ...         ...       ...          ...     ...
# 995       False  False       False     False        False   False
# 996       False  False       False     False        False   False
# 997       False  False       False     False        False   False
# 998       False  False       False     False        False   False
# 999       False  False       False     False        False    True
#
#      PerformanceScore  BonusEligible  Gender    Age  WorkFromHome  \
# 0               False          False   False  False         False
# ...

# %%
employees_df['Department'].isna()  # to know the missing values in a specific column (will give only boolean values )
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Department, Length: 1000, dtype: bool

# %%
employees_df.isna().sum() # to get get the count of nan values column wise
# Out:
# EmployeeID          0
# Name                0
# Department          0
# Location            0
# JoiningDate         0
# Salary              0
# PerformanceScore    0
# BonusEligible       0
# Gender              0
# Age                 0
# WorkFromHome        0
# ProjectsHandled     0
# Certifications      0
# dtype: int64

# %%
employees_df.isna().sum().sum() # to get get the count of nan values in entire df
# Out:
# np.int64(296)

# %%
# filling missing values
employees_df['PerformanceScore'].fillna(80,inplace=True) # fill a constant value in the specific column (modifies the original data frame)
# Out:
# C:\Users\heman\AppData\Local\Temp\ipykernel_28208\915698131.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   employees_df['PerformanceScore'].fillna(80,inplace=True)

# %%
employees_df.fillna({'salary':employees_df['Salary'].mean()}, inplace=True)

# %%
employees_df.fillna(method="ffill",inplace=True)
# Out:
# C:\Users\heman\AppData\Local\Temp\ipykernel_28208\2745529812.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   employees_df.fillna(method="ffill",inplace=True)

# %%
# Identifying Duplicates 
employees_df.duplicated().sum() # will give you the total of duplicated values
# Out:
# np.int64(0)

# %%
# drop duplicates
employees_df.drop_duplicates()
# Out:
#      EmployeeID             Name   Department  Location JoiningDate  \
# 0          1001   William Chaney    Marketing    Boston  2024-08-23
# 1          1002    Andre Stewart        Sales   Seattle  2016-07-27
# 2          1003  Nicole Sandoval      Finance    Austin  2022-10-10
# 3          1004      Billy Lopez        Sales  New York  2017-02-01
# 4          1005    Charles Wyatt        Sales    Austin  2016-05-10
# ..          ...              ...          ...       ...         ...
# 995        1996  Margaret Duncan           IT   Seattle  2018-06-01
# 996        1997    Corey Johnson        Sales  New York  2024-04-13
# 997        1998     Samuel White  Engineering  New York  2020-10-01
# 998        1999     Andrew Clark  Engineering    Austin  2024-05-19
# 999        2000     John Salazar        Sales    Boston  2019-06-22
#
#             Salary  PerformanceScore  BonusEligible  Gender  Age  \
# 0    160169.000000              4.65          False   Other   55
# ...

# %%
# Exploring Data with Grouping and Aggregation 
groupped_department = employees_df.groupby('Department')
groupped_department['Salary'].count() # single aggrigation value
# Out:
# Department
# Engineering    178
# Finance        155
# HR             164
# IT             153
# Marketing      176
# Sales          174
# Name: Salary, dtype: int64

# %%
groupped_department['Salary'].agg(['mean','sum','max']) # getting multiple aggrigations
# Out:
#                       mean           sum       max
# Department
# Engineering  122886.638140  2.187382e+07  197977.0
# Finance      119366.296605  1.850178e+07  199130.0
# HR           125774.984676  2.062710e+07  199340.0
# IT           127487.452486  1.950558e+07  198087.0
# Marketing    125603.856347  2.210628e+07  199817.0
# Sales        121605.274236  2.115932e+07  198781.0

# %%
groupped_department['Salary'].agg(lambda x  : x.max() - x.min())
# Out:
# Department
# Engineering    147814.0
# Finance        147953.0
# HR             147317.0
# IT             208087.0
# Marketing      209817.0
# Sales          208781.0
# Name: Salary, dtype: float64

# %%
employees_df['Salary'].plot(kind='hist' , bins=20)  # plotting salary data on histogram
# Out:
# <Axes: ylabel='Frequency'>

# %%
employees_df.plot(kind="scatter",x="Salary",y="Age")
# Out:
# <Axes: xlabel='Salary', ylabel='Age'>
